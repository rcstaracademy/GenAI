# %%
def removeOutliers(data, num_outliers):
    retval = sorted(data)  #  2 3 6 12 67 88 900

    for i in range(num_outliers):
        retval.pop()

    for i in range(num_outliers):
        retval.pop(0)

    return retval

# %%
def main():
    values = []
    s = input("Enter a value (blank line to quit): ")
    while s!= "":
        num = float(s)
        values.append(num)
        s = input("Enter a value (blank line to quit): ")

    if len(values) < 4:
        print("You did not enter enough values")
    else:
        print("With the outliers removed: ", removeOutliers(values,1))
        print("The original data: ", values)

main()
# Out:
# Enter a value (blank line to quit): 45
# Enter a value (blank line to quit): 44
# Enter a value (blank line to quit): 55
# Enter a value (blank line to quit): 66
# Enter a value (blank line to quit): 33
# Enter a value (blank line to quit): 44
# Enter a value (blank line to quit): 55
# Enter a value (blank line to quit): 78
# Enter a value (blank line to quit): 88
# Enter a value (blank line to quit): 34
# Enter a value (blank line to quit):
# With the outliers removed:  [34.0, 44.0, 44.0, 45.0, 55.0, 55.0, 66.0, 78.0]
# The original data:  [45.0, 44.0, 55.0, 66.0, 33.0, 44.0, 55.0, 78.0, 88.0, 34.0]
